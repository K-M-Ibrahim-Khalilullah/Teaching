# %% [markdown]
# # ----------- $ Home Work $ -------------
#
# # Project Description
#
# The Iris dataset is a classic benchmark dataset in statistics and machine learning. It contains 150 samples of iris flowers, divided equally among three distinct species: Iris setosa (characterized by relatively smaller sepals and petals), Iris versicolor (medium-sized), and Iris virginica (the largest). To help machine learning algorithms classify and predict these flower species, four physical measurements are recorded in centimeters for each sample: Sepal Length, Sepal Width, Petal Length, and Petal Width. Sepal Length and Sepal Width measure the dimensions of the outer sepals that protect the flower bud, while Petal Length and Petal Width measure the dimensions of the inner petals.
#
# ![Irish Dataset](<../../../Shared-Resources/images/irish_flower.png>)
#
#
# <!-- we can use it as an alterntive way
# ![Iris Dataset](../../../../Shared%20Resources/images/irish_flower.png) -->
#
# <!-- Reminding myself:
# <img src="../../../../Shared Resources/images/irish_flower.png">
# -->
#
# Our goal is to classify the flowers using k-NN.

# %%
## import packages
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
## Load Data
iris = pd.read_csv('../../../../Shared Resources/Dataset/Iris.csv')
# first 5 rows of data
iris.head()

# %%
fig = iris[iris.Species=='Iris-setosa'].plot(kind='scatter',x='SepalLengthCm',y='SepalWidthCm',color='orange', label='Setosa')
iris[iris.Species=='Iris-versicolor'].plot(kind='scatter',x='SepalLengthCm',y='SepalWidthCm',color='blue', label='versicolor',ax=fig)
iris[iris.Species=='Iris-virginica'].plot(kind='scatter',x='SepalLengthCm',y='SepalWidthCm',color='green', label='virginica', ax=fig)
fig.set_xlabel("Sepal Length")
fig.set_ylabel("Sepal Width")
fig.set_title("Sepal Length VS Width")
fig=plt.gcf()
fig.set_size_inches(10,6)
plt.show()

# %%
fig = iris[iris.Species=='Iris-setosa'].plot.scatter(x='PetalLengthCm',y='PetalWidthCm',color='orange', label='Setosa')
iris[iris.Species=='Iris-versicolor'].plot.scatter(x='PetalLengthCm',y='PetalWidthCm',color='blue', label='versicolor',ax=fig)
iris[iris.Species=='Iris-virginica'].plot.scatter(x='PetalLengthCm',y='PetalWidthCm',color='green', label='virginica', ax=fig)
fig.set_xlabel("Petal Length")
fig.set_ylabel("Petal Width")
fig.set_title(" Petal Length VS Width")
fig=plt.gcf()
fig.set_size_inches(10,6)
plt.show()

# %%
# ============================================================
# Data Preprocessing: Known Instances
# ============================================================

# Remove Id column
iris = iris.drop("Id", axis=1)

# Select only two features
X = iris[["PetalLengthCm", "PetalWidthCm"]]

# Target
y = iris["Species"]

print("Features")
display(X.head())

print("Target")
display(y.head())

# %%
# ============================================================
# Unknown Flower/Unknown Instances
# ============================================================

unknown = pd.DataFrame({

    "PetalLengthCm":[4.8],
    "PetalWidthCm":[1.7]

})

display(unknown)

# %% [markdown]
# Now it's your task. you will implement the K-Nearest Neighbors (KNN) algorithm from scratch using the Iris dataset, following the same steps demonstrated for the loan dataset in class.  The dataset has already been loaded and preprocessed for you. I have selected only two features: *PetalLengthCm* and *PetalWidthCm*.
#
# *Tasks:*
# 1. Standardize the Features
#     - Normalize the two selected features using StandardScaler.
#     - Display the first five rows of the normalized data.
# 2. Create an Unknown Flower
#     - Normalize the unknown sample using the same scaler used for known instances.
# 3. Compute Euclidean Distances
#     - Calculate the Euclidean distance between the unknown flower and every sample in the normalized dataset.
#     - Store all computed distances.
# 4. Add the Distance Column
#     - Create a copy of the original dataset.
#     - Add a new column named Distance containing the calculated distances.
# 5. Sort by Distance
#     - Sort the dataset in ascending order based on the Distance column.
#     - Display the first 10 nearest samples.
# 6. Find the K Nearest Neighbors
#     - Use K = 3.
#     - Select the three nearest neighbors.
#     - Display their feature values, species, and distances.
# 7. Predict the Species
#     - Apply majority voting using the three nearest neighbors.
#     - Display the predicted species of the unknown flower.
# 8. Visualization
#     - Create a scatter plot using:
#         - X-axis: PetalLengthCm
#         - Y-axis: PetalWidthCm
#     - Plot each iris species using a different marker or color.
#     - Plot the unknown flower using a distinct marker.
#     - Highlight the three nearest neighbors.
#     - Draw dashed lines from the unknown flower to each of the three nearest neighbors.
